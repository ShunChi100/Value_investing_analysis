# %% [markdown]
# # Stock Ticker Symbol Data cleaning

# %% [markdown]
# The ticker symbol data is downloaded from [NASDAQ.com](http://www.nasdaq.com/screening/company-list.aspx). For this project we would like to select stocks with marketcapital larger than 10 billion.

# %%
import requests
import pandas as pd
import numpy as np
import time
import feather
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Read data

# %%
# read ticker symbols from all US stocks, data source (http://www.nasdaq.com/screening/company-list.aspx)
tickers_NASDAQ = pd.read_csv("../data/data_Ticker/NASDAQ.csv", skiprows=None)
tickers_NASDAQ ["Exchange"] = "NASDAQ"
tickers_NASDAQ = tickers_NASDAQ.drop("Unnamed: 8", axis=1)

tickers_NYSE = pd.read_csv("../data/data_Ticker/NYSE.csv", skiprows=None)
tickers_NYSE ["Exchange"] = "NYSE"
tickers_NYSE = tickers_NYSE.drop("Unnamed: 8", axis=1)

tickers_AMEX = pd.read_csv("../data/data_Ticker/AMEX.csv", skiprows=None)
tickers_AMEX ["Exchange"] = "AMEX"
tickers_AMEX = tickers_AMEX.drop("Unnamed: 8", axis=1)

# combine all symbols from three exchanges into one dataframe
tickers = tickers_NASDAQ.append(tickers_NYSE)
tickers = tickers.append(tickers)

# %%
tickers.head(5)
# Out:
#   Symbol                                    Name LastSale MarketCap IPOyear  \
# 0    PIH  1347 Property Insurance Holdings, Inc.      7.4   $44.29M    2014
# 1   TURN                180 Degree Capital Corp.     2.03   $63.18M     n/a
# 2   FLWS                 1-800 FLOWERS.COM, Inc.      9.5  $613.93M    1999
# 3   FCCY           1st Constitution Bancorp (NJ)    17.95  $144.91M     n/a
# 4   SRCE                  1st Source Corporation    49.88    $1.29B     n/a
#
#               Sector                    industry  \
# 0            Finance  Property-Casualty Insurers
# 1            Finance  Finance/Investors Services
# 2  Consumer Services      Other Specialty Stores
# 3            Finance        Savings Institutions
# 4            Finance                 Major Banks
#
#                        Summary Quote Exchange
# 0   http://www.nasdaq.com/symbol/pih   NASDAQ
# 1  http://www.nasdaq.com/symbol/turn   NASDAQ
# 2  http://www.nasdaq.com/symbol/flws   NASDAQ
# 3  http://www.nasdaq.com/symbol/fccy   NASDAQ
# 4  http://www.nasdaq.com/symbol/srce   NASDAQ

# %% [markdown]
# ### Clean data
# There are many duplicated symbols, uncommon symbols, and one symbol with multiple classes of stocks. For example, all symbols for "Bank of America Corporation" is shown below.

# %%
tickers.loc[tickers.Name == "Bank of America Corporation"]
# Out:
#        Symbol                         Name LastSale MarketCap IPOyear  \
# 320       BAC  Bank of America Corporation    26.62  $277.66B     n/a
# 321  BAC.WS.A  Bank of America Corporation      n/a       n/a     n/a
# 322  BAC.WS.B  Bank of America Corporation      n/a       n/a     n/a
# 323     BAC^A  Bank of America Corporation    26.94       n/a     n/a
# 324     BAC^C  Bank of America Corporation    27.28       n/a     n/a
# 325     BAC^D  Bank of America Corporation    25.98       n/a     n/a
# 326     BAC^E  Bank of America Corporation    23.73       n/a     n/a
# 327     BAC^I  Bank of America Corporation    26.61       n/a     n/a
# 323      n/a          n/a     http://www.nasdaq.com/symbol/bac^a     NYSE
# 324      n/a          n/a     http://www.nasdaq.com/symbol/bac^c     NYSE
# 325      n/a          n/a     http://www.nasdaq.com/symbol/bac^d     NYSE
# 326      n/a          n/a     http://www.nasdaq.com/symbol/bac^e     NYSE
# 327      n/a          n/a     http://www.nasdaq.com/symbol/bac^i     NYSE
# 328      n/a          n/a     http://www.nasdaq.com/symbol/bac^l     NYSE
# 329  Finance  Major Banks     http://www.nasdaq.com/symbol/bac^w     NYSE
# 330  Finance  Major Banks     http://www.nasdaq.com/symbol/bac^y     NYSE
# 331      n/a          n/a     http://www.nasdaq.com/symbol/bml^g     NYSE
# 332      n/a          n/a     http://www.nasdaq.com/symbol/bml^h     NYSE
# 333      n/a          n/a     http://www.nasdaq.com/symbol/bml^i     NYSE
# 334      n/a          n/a     http://www.nasdaq.com/symbol/bml^j     NYSE
# 335      n/a          n/a     http://www.nasdaq.com/symbol/bml^l     NYSE

# %% [markdown]
# __Data cleaning:__
#
# * remove symbols with `^`
# * reomve symbols without stock price `LastSale == n/a`
# * reomve symbols without market captical `MarketCap == n/a`

# %%
# remove stocks with ^ signs
data_size = tickers.shape
data_size = np.arange(data_size[0])   # give a integer vector for indexing in tickers.
tickers = tickers.reset_index()     # reset index after joining multiple dataframes
tickers.drop(list(data_size[tickers.Symbol.str.contains("\^").tolist()]),axis = 0, inplace=True)
tickers = tickers.reset_index()    # reset index after deleting some rows

# drop colums created when reseting index.
tickers.drop(["level_0","index"], axis=1, inplace=True)  

# reomve symbols without market captical `MarketCap == n/a`
tmp = tickers.shape
tmp = np.arange(tmp[0])
tickers.drop(list(tmp[tickers.MarketCap=="n/a"]),axis = 0, inplace=True)
tickers = tickers.reset_index()

# delete duplicated names
tickers.drop_duplicates(["Name"], inplace=True)

# delete rows with Sector == n/a
tmp = tickers.shape
tmp = np.arange(tmp[0])
tickers = tickers.reset_index()
tickers.drop(["level_0","index"], axis=1, inplace=True)
tickers.drop(list(tmp[tickers.Sector=="n/a"]),axis = 0, inplace=True)
tickers = tickers.reset_index()

# drop colums created when reseting index.
tickers.drop(["index"], axis=1, inplace=True)
tickers.head(5)

tickers.describe()
# Out:
#   Symbol                                    Name LastSale MarketCap IPOyear  \
# 0    PIH  1347 Property Insurance Holdings, Inc.      7.4   $44.29M    2014
# 1   TURN                180 Degree Capital Corp.     2.03   $63.18M     n/a
# 2   FLWS                 1-800 FLOWERS.COM, Inc.      9.5  $613.93M    1999
# 3   FCCY           1st Constitution Bancorp (NJ)    17.95  $144.91M     n/a
# 4   SRCE                  1st Source Corporation    49.88    $1.29B     n/a
#
#               Sector                    industry  \
# 0            Finance  Property-Casualty Insurers
# 1            Finance  Finance/Investors Services
# 2  Consumer Services      Other Specialty Stores
# 3            Finance        Savings Institutions
# 4            Finance                 Major Banks
#
#                        Summary Quote Exchange
# 0   http://www.nasdaq.com/symbol/pih   NASDAQ
# 1  http://www.nasdaq.com/symbol/turn   NASDAQ
# 2  http://www.nasdaq.com/symbol/flws   NASDAQ
# 3  http://www.nasdaq.com/symbol/fccy   NASDAQ
# 4  http://www.nasdaq.com/symbol/srce   NASDAQ
#        Symbol             Name LastSale MarketCap IPOyear   Sector  \
# count    4508             4508     4508      4508    4508     4508
# unique   4508             4508     3225      3442      41       12
# top      CORT  YogaWorks, Inc.     3.75    $1.37B     n/a  Finance
# freq        1                1        8        13    2312      795
#
#                      industry                    Summary Quote Exchange
# count                    4508                             4508     4508
# unique                    136                             4508        2
# top     Major Pharmaceuticals  http://www.nasdaq.com/symbol/ts   NASDAQ
# freq                      383                                1     2529

# %%
tickers.loc[tickers.Name == "Bank of America Corporation"]
# Out:
#      Symbol                         Name LastSale MarketCap IPOyear   Sector  \
# 2736    BAC  Bank of America Corporation    26.62  $277.66B     n/a  Finance
#
#          industry                     Summary Quote Exchange
# 2736  Major Banks  http://www.nasdaq.com/symbol/bac     NYSE

# %% [markdown]
# ### Select tickers with only market cap larger than 10 Billion

# %% [markdown]
# Here we only select stocks with market cap that is larger than 10 billion in 2017-11. To do that, we can first select rows in which `MarketCap` column contains `B` (billion). Then covert the type to numeric and selecting values larger than 10.

# %%
# select ticker symbols with `MarketCap` contains "B"
tickers_Billion = tickers.loc[tickers.MarketCap.str.contains("B")]
tickers_Billion.describe()

# see the filtered symbols
tickers_Billion = tickers_Billion.reset_index();
tickers_Billion.drop(["index"], axis=1, inplace=True)
tickers_Billion.head(5)
# Out:
#        Symbol                     Name LastSale MarketCap IPOyear  \
# count    2253                     2253     2253      2253    2253
# unique   2253                     2253     2011      1226      41
# top       XON  Acco Brands Corporation    44.75    $1.37B     n/a
# freq        1                        1        4        13    1191
#
#                    Sector                       industry  \
# count                2253                           2253
# unique                 12                            129
# top     Consumer Services  Real Estate Investment Trusts
# freq                  394                            142
#
#                            Summary Quote Exchange
# count                               2253     2253
# unique                              2253        2
# top     http://www.nasdaq.com/symbol/eqm     NYSE
# freq                                   1     1465
#   Symbol                        Name LastSale MarketCap IPOyear  \
# 0   SRCE      1st Source Corporation    49.88    $1.29B     n/a
# 1   TWOU                    2U, Inc.    63.67    $3.32B    2014
# 2   JOBS                 51job, Inc.    62.57    $3.87B    2004
# 3   CAFD  8point3 Energy Partners LP    14.94    $1.18B    2015
# 4   EGHT                     8x8 Inc    14.05    $1.29B     n/a
#
#              Sector                                 industry  \
# 0           Finance                              Major Banks
# 1        Technology  Computer Software: Prepackaged Software
# 2        Technology          Diversified Commercial Services
# 3  Public Utilities              Electric Utilities: Central
# 4  Public Utilities             Telecommunications Equipment
#
#                        Summary Quote Exchange
# 0  http://www.nasdaq.com/symbol/srce   NASDAQ
# 1  http://www.nasdaq.com/symbol/twou   NASDAQ
# 2  http://www.nasdaq.com/symbol/jobs   NASDAQ
# 3  http://www.nasdaq.com/symbol/cafd   NASDAQ
# 4  http://www.nasdaq.com/symbol/eght   NASDAQ

# %%
# convert last sale price type to numeric
tickers_Billion.loc[:,"LastSale"] = tickers_Billion.loc[:,"LastSale"].astype(float);

# remove $ and B in `MarketCap`
tmp = tickers_Billion.MarketCap.str.replace("$", "")
tmp = tmp.str.replace("B", "")
#tmp.reset_index()

# change marketcap to real numercial values.
tickers_Billion.MarketCap= tmp.astype(float) * 1000000000

tickers_Billion.head()
# Out:
#   Symbol                        Name  LastSale     MarketCap IPOyear  \
# 0   SRCE      1st Source Corporation     49.88  1.290000e+09     n/a
# 1   TWOU                    2U, Inc.     63.67  3.320000e+09    2014
# 2   JOBS                 51job, Inc.     62.57  3.870000e+09    2004
# 3   CAFD  8point3 Energy Partners LP     14.94  1.180000e+09    2015
# 4   EGHT                     8x8 Inc     14.05  1.290000e+09     n/a
#
#              Sector                                 industry  \
# 0           Finance                              Major Banks
# 1        Technology  Computer Software: Prepackaged Software
# 2        Technology          Diversified Commercial Services
# 3  Public Utilities              Electric Utilities: Central
# 4  Public Utilities             Telecommunications Equipment
#
#                        Summary Quote Exchange
# 0  http://www.nasdaq.com/symbol/srce   NASDAQ
# 1  http://www.nasdaq.com/symbol/twou   NASDAQ
# 2  http://www.nasdaq.com/symbol/jobs   NASDAQ
# 3  http://www.nasdaq.com/symbol/cafd   NASDAQ
# 4  http://www.nasdaq.com/symbol/eght   NASDAQ

# %% [markdown]
# __Select Market Cap larger than 10 billions__

# %%
tickers_TenBillion = tickers_Billion.loc[tickers_Billion.MarketCap > 10000000000]

tickers_TenBillion = tickers_TenBillion.reset_index()
tickers_TenBillion.drop(["index"], axis=1, inplace=True)

tickers_TenBillion.head()
tickers_TenBillion.shape
# Out:
#   Symbol                           Name  LastSale     MarketCap IPOyear  \
# 0   ATVI       Activision Blizzard, Inc     64.10  4.847000e+10     n/a
# 1   ADBE     Adobe Systems Incorporated    182.24  8.983000e+10    1986
# 2    AMD   Advanced Micro Devices, Inc.     11.38  1.098000e+10     n/a
# 3   ALXN  Alexion Pharmaceuticals, Inc.    110.87  2.477000e+10    1996
# 4   ALGN         Align Technology, Inc.    253.89  2.036000e+10    2001
#
#         Sector                                 industry  \
# 0   Technology  Computer Software: Prepackaged Software
# 1   Technology  Computer Software: Prepackaged Software
# 2   Technology                           Semiconductors
# 3  Health Care                    Major Pharmaceuticals
# 4  Health Care                   Industrial Specialties
#
#                        Summary Quote Exchange
# 0  http://www.nasdaq.com/symbol/atvi   NASDAQ
# 1  http://www.nasdaq.com/symbol/adbe   NASDAQ
# 2   http://www.nasdaq.com/symbol/amd   NASDAQ
# 3  http://www.nasdaq.com/symbol/alxn   NASDAQ
# 4  http://www.nasdaq.com/symbol/algn   NASDAQ
# (666, 9)

# %% [markdown]
# #### Save the ticker symbols dataframe to feature (for read in R)

# %%
# Write to a csv file
tickers_TenBillion.to_csv("../data/data_Ticker/tickers_TenBillion.csv")

# Write to a feather file for R
feather.write_dataframe(tickers_TenBillion, "../data/data_Ticker/tikers_TenBillion.feather")
